# %% [markdown]
# ### When you answer your questions, please use [emoji](https://getemoji.com/) and [good markdown](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html) so that it is easy for Mahyar to find your work and grade it. Thanks!

# %% [markdown]
# Be sure to put your name here:
# *  Md Arifuzzaman Faisal

# %% [markdown]
# ____
#
# # HW #3
#
# ____

# %% [markdown]
# ____
# ## GitHub
#
# It is important to have a public place to show your work, and GitHub (GH) is one of the standards you need to know for this. By the end of the semester you will have GH repos (repositories) for both of your projects. Among other goals, this will allow you to show off your work!
#
# I expect that the students in this class have very different experiences with GH, so this problem might be really short or really long.
#
# ✍🏻 (5pts) First, make a GH account for yourself [here](https://github.com/). Put your GH account information in a markdown cell. If you already have a GH repo, you do not need to create a new one; just put the name in the markdown cell. Or, create a new account for this class. I would like to collect the projects in one place so that we can all see them, even after the class is over.
#
# If you want to brush up on GH, or learn it from scratch, I recommend watching some YouTube videos. I recommend [this one](https://www.youtube.com/watch?v=x0EYpi38Yp4), or [this one](https://www.youtube.com/watch?v=DVRQoVRzMIY) and this pair: [first one](https://www.youtube.com/watch?v=USjZcfj8yxE) and [second one](https://www.youtube.com/watch?v=nhNq2kIvi9s).
#
# If you have any questions, please ask us! We are here to help!
#
# ✍🏻 (2 pts) Second, once you have your personal GH repo setup, practice by putting your web apps from this class there.
#
# Put a link to your web app here so that Mahyar can check to see that it worked.

# %% [markdown]
# ### My Github Page
#
# #### Link: https://github.com/faisalece
# #### CMSE 830 Repo: https://github.com/faisalece/cmse830
# #### HW 3: https://github.com/faisalece/cmse830/tree/main/HW

# %% [markdown]
# ____
# ## Project Practice
#
# This week you are going to practice for your midterm project. The midterm project is DS and the final project is machine learning (ML). What we want to explore in this problem is what we can do with DS.
#
# You will choose the topic of your project. This means:
# * you can use a dataset that you have from your job,
# * you can use a dataset that leads to a publication,
# * or, you can use a standard dataset if you don't have your own.
#
# The point is that this is flexible and can scale with each student. What I don't recommend is building your own dataset. While I would very much love to see that, there is a risk that it will take too long and possibly not lead to anything. (If you really want to do that, contact me!)
#
# Because the projects will be quite different, the instructions will be somewhat vague on purpose. But, here are the rules:
# 1. use most of the tools of EDA,
# 2. use visualization at a professional level (which we will cover soon),
# 3. be as quantitive as possible, using statistical tools,
# 4. have a question or goal in mind -- **a story**; or, if you explore a dataset, you should reach a new conclusion or observation about the dataset,
# 5. the final result will be a web app that others can access. (I will walk you through using `streamlit` with `GitHub` and `Heroku`, but talk to me if you want to use any of the many other options.)
#
# ✍🏻 (15 pts) Pick **three** datasets - your choice. You can find a lot of datasets [here](https://archive.ics.uci.edu/); search for topics that are of most interest to you. From these three datasets, write code to perform EDA on them and put that below. Below the EDA code cells for each dataset, open a markdown cell and write a paragraph that answers these questions:
# 1. why did you pick this dataset?
# 2. are there any interesting insights you gained from performing EDA on this dataset? (use all/most of the Seaborn tools we discussed this week)
# 3. are there any actionable insights you can get from this data? (For example, if you were a CEO and looking at the mpg dataset, what might you conclude?)
#
# Finally, open a new markdown and discuss which of these three datasets would make the best project dataset. Were some of the datasets disappointing? Was one of the datasets much richer with possibilities? The reason you are asked to pick three is that some datasets is that you need to be able to assess which datasets are more or less interesting for your projects.
#
# [Here is an example you can follow that uses a wine dataset.](https://murillogroupmsu.com/wine/) It is also [at GH](https://gist.github.com/MurilloGroupMSU/678f61bbe225bdd166e8b946765d2931).

# %% [markdown]
# ### Dataset 1 : Water Quality
# #### Link: https://www.kaggle.com/datasets/adityakadiwal/water-potability

# %%
import pandas as pd
import seaborn as sns

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Import the dataset using Pandas
df_1 = pd.read_csv('water_potability.csv')
df_1
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# 1       592.885359       15.180013        56.329076   4.500656           0
# 2       418.606213       16.868637        66.420093   3.055934           0
# 3       363.266516       18.436524       100.341674   4.628771           0
# 4       398.410813       11.558279        31.997993   4.075075           0
# ...            ...             ...              ...        ...         ...
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1
#
# [3276 rows x 10 columns]

# %%
df_1.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df_1.tail()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1

# %%
df_1.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
df_1.isna()
# Out:
#          ph  Hardness  Solids  Chloramines  Sulfate  Conductivity  \
# 0      True     False   False        False    False         False
# 1     False     False   False        False     True         False
# 2     False     False   False        False     True         False
# 3     False     False   False        False    False         False
# 4     False     False   False        False    False         False
# ...     ...       ...     ...          ...      ...           ...
# 3271  False     False   False        False    False         False
# 3272  False     False   False        False     True         False
# 3273  False     False   False        False     True         False
# 3274  False     False   False        False     True         False
# 3275  False     False   False        False     True         False
#
#       Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0              False            False      False       False
# 1              False            False      False       False
# 2              False            False      False       False
# 3              False            False      False       False
# 4              False            False      False       False
# ...              ...              ...        ...         ...
# 3271           False            False      False       False
# 3272           False             True      False       False
# 3273           False            False      False       False
# 3274           False            False      False       False
# 3275           False            False      False       False
#
# [3276 rows x 10 columns]

# %%
ax = df_1.plot.kde(subplots=True, layout=(3,4), figsize=(16, 6), sharex=False, legend=False)
# Add space between subplots
plt.subplots_adjust(hspace=0.5, wspace=0.5)

# Adding labels to axes
for i, axes_row in enumerate(ax):
    for j, ax in enumerate(axes_row):
        ax.set_xlabel(df_1.columns[i*2+j])
        ax.set_ylabel('Density')

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=df_1, x=df_1.columns[3], y=df_1.columns[1], lowess=True, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.show()

# %%
df_1.hist(bins=10, figsize=(12, 8), layout=(3, 4))

plt.suptitle('Water Quality', y=1.03)    
plt.tight_layout()

plt.show()

# %%
# Seaborn very easily understands what we would like to do.
#sns.boxplot(x='Hardness', y='Solids', hue='Potability', data=df_1)
# Discretize the x-axis variable into 10 categories
plt.figure(figsize=(15, 6))
df_1['Hard'] = pd.cut(df_1['Hardness'], bins=10)
sns.boxplot(x='Hard', y='Solids', hue='Potability', data=df_1, dodge=True)
# Out:
# <AxesSubplot:xlabel='Hard', ylabel='Solids'>

# %%
df_1.corr()
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.082096 -0.089288    -0.034350  0.018203
# Hardness         0.082096  1.000000 -0.046899    -0.030054 -0.106923
# Solids          -0.089288 -0.046899  1.000000    -0.070148 -0.171804
# Chloramines     -0.034350 -0.030054 -0.070148     1.000000  0.027244
# Sulfate          0.018203 -0.106923 -0.171804     0.027244  1.000000
# Conductivity     0.018614 -0.023915  0.013831    -0.020486 -0.016121
# Organic_carbon   0.043503  0.003610  0.010242    -0.012653  0.030831
# Trihalomethanes  0.003354 -0.013013 -0.009143     0.017084 -0.030274
# Turbidity       -0.039057 -0.014449  0.019546     0.002363 -0.011187
# Potability      -0.003556 -0.013837  0.033743     0.023779 -0.023577
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.018614        0.043503         0.003354  -0.039057
# Hardness            -0.023915        0.003610        -0.013013  -0.014449
# Solids               0.013831        0.010242        -0.009143   0.019546
# Chloramines         -0.020486       -0.012653         0.017084   0.002363
# Sulfate             -0.016121        0.030831        -0.030274  -0.011187
# Conductivity         1.000000        0.020966         0.001285   0.005798
# Organic_carbon       0.020966        1.000000        -0.013274  -0.027308
# Trihalomethanes      0.001285       -0.013274         1.000000  -0.022145
# Turbidity            0.005798       -0.027308        -0.022145   1.000000
# Potability          -0.008128       -0.030001         0.007130   0.001581
#
#                  Potability
# ph                -0.003556
# Hardness          -0.013837
# Solids             0.033743
# Chloramines        0.023779
# Sulfate           -0.023577
# Conductivity      -0.008128
# Organic_carbon    -0.030001
# Trihalomethanes    0.007130
# Turbidity          0.001581
# Potability         1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_1.corr(), annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
attribute1="ph"
attribute2="Conductivity"
sns.jointplot(data=df_1, x=attribute1, y=attribute2, hue="Potability")

# %% [markdown]
# #### Pair Plot

# %%
g = sns.PairGrid(df_1, x_vars=['ph', 'Hardness', 'Solids', 'Conductivity', 'Trihalomethanes'], y_vars=['ph', 'Hardness', 'Solids', 'Conductivity', 'Trihalomethanes'], hue='Potability')
g = g.map_upper(plt.scatter)
#g = g.map(sns.regplot, color=".3")
g = g.map_diag(plt.hist, histtype="step", linewidth=2, bins=30)
# g = g.map_diag(plt.hist)
# g = g.map_offdiag(plt.scatter)
#g = g.map_lower(sns.kdeplot)
g = g.map_lower(plt.scatter)
g = g.add_legend()

# %% [markdown]
# 1. why did you pick this dataset?
# 2. are there any interesting insights you gained from performing EDA on this dataset? (use all/most of the Seaborn tools we discussed this week)
# 3. are there any actionable insights you can get from this data? (For example, if you were a CEO and looking at the mpg dataset, what might you conclude?)
#
# #### 1. I chose the Water Potability dataset because it addresses a critical global issue - access to safe drinking water. Understanding the factors that affect water potability can have significant implications for public health and policy-making.
# #### 2. By creating a correlation heatmap, I found that there is a moderate negative correlation between the pH level and potability. This suggests that pH may be an important factor in determining water potability.
# #### 3. EDA results provide valuable insights for various stakeholders. For instance, it might be crucial to invest in technologies that effectively regulate and maintain the pH levels of water sources. Additionally, understanding the relationship between chloramines and potability could lead to improved water treatment processes to ensure safe drinking water for communities.

# %% [markdown]
# ### Dataset 2 : Stroke Prediction Dataset
# #### Link: https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset

# %%
# Import the dataset using Pandas
df_2 = pd.read_csv('stroke-data.csv')
df_2
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
df_2.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df_2.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
df_2.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df_2.isna()
# Out:
#          id  gender    age  hypertension  heart_disease  ever_married  \
# 0     False   False  False         False          False         False
# 1     False   False  False         False          False         False
# 2     False   False  False         False          False         False
# 3     False   False  False         False          False         False
# 4     False   False  False         False          False         False
# ...     ...     ...    ...           ...            ...           ...
# 5105  False   False  False         False          False         False
# 5106  False   False  False         False          False         False
# 5107  False   False  False         False          False         False
# 5108  False   False  False         False          False         False
# 5109  False   False  False         False          False         False
#
#       work_type  Residence_type  avg_glucose_level    bmi  smoking_status  \
# 0         False           False              False  False           False
# 1         False           False              False   True           False
# 2         False           False              False  False           False
# 3         False           False              False  False           False
# 4         False           False              False  False           False
# ...         ...             ...                ...    ...             ...
# 5105      False           False              False   True           False
# 5106      False           False              False  False           False
# 5107      False           False              False  False           False
# 5108      False           False              False  False           False
# 5109      False           False              False  False           False
#
#       stroke
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 5105   False
# 5106   False
# 5107   False
# 5108   False
# 5109   False
#
# [5110 rows x 12 columns]

# %%
df_new = df_2.select_dtypes(include=['int64', 'float64'])
plt.figure(figsize=(10, 10))
sns.heatmap(df_new.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
ax = df_2.plot.kde(subplots=True, layout=(2,4), figsize=(18, 6), sharex=False, legend=False)
# Add space between subplots
plt.subplots_adjust(hspace=0.5, wspace=0.5)

# Adding labels to axes
for i, axes_row in enumerate(ax):
    for j, ax in enumerate(axes_row):
        ax.set_xlabel(df_2.columns[i*2+j])
        ax.set_ylabel('Density')

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=df_2, x=df_2.columns[8], y=df_2.columns[9], lowess=True, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.show()

# %%
df_2.hist(bins=10, figsize=(12, 8), layout=(3, 4), color='skyblue', edgecolor='black')

plt.suptitle('Stroke  Data', y=1.03)    
plt.tight_layout()

plt.show()

# %%
attribute1=df_2.columns[8]
attribute2=df_2.columns[9]
sns.jointplot(data=df_2, x=attribute1, y=attribute2, hue="gender")

# %%
# Discretize the x-axis variable into 10 categories
plt.figure(figsize=(15, 6))
df_2['Age'] = pd.cut(df_2[df_2.columns[2]], bins=10)
sns.boxplot(x='Age', y=df_2.columns[9], hue='gender', data=df_2, dodge=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='bmi'>

# %% [markdown]
# #### Pair Plot

# %%
g = sns.PairGrid(df_2, x_vars=['age', 'avg_glucose_level', 'bmi'], y_vars=['age', 'avg_glucose_level', 'bmi'], hue='gender')
g = g.map_upper(plt.scatter)
#g = g.map(sns.regplot, color=".3")
g = g.map_diag(plt.hist, histtype="step", linewidth=2, bins=30)
# g = g.map_diag(plt.hist)
# g = g.map_offdiag(plt.scatter)
#g = g.map_lower(sns.kdeplot)
g = g.map_lower(plt.scatter)
g = g.add_legend()

# %% [markdown]
# 1. why did you pick this dataset?
# 2. are there any interesting insights you gained from performing EDA on this dataset? (use all/most of the Seaborn tools we discussed this week)
# 3. are there any actionable insights you can get from this data? (For example, if you were a CEO and looking at the mpg dataset, what might you conclude?)
#
# #### 1. The Stroke Prediction dataset was chosen due to its critical relevance in healthcare. Understanding the factors contributing to strokes can lead to improved preventative measures and healthcare strategies.
# #### 2. Through a histogram, I observed that the majority of individuals in the dataset were between 40 and 70 years old, with a peak around 60. This suggests that strokes may be more prevalent in this age group.
# #### 3. EDA results provide valuable insights would be crucial for shaping preventative health strategies. For instance, there could be an increased focus on health education and screening programs for individuals in the 40-70 age range. Additionally, efforts to manage and prevent hypertension, as well as maintaining healthy BMI levels, could be prioritized to reduce stroke risk.

# %% [markdown]
# ### Dataset 3 : Life Expectancy (WHO) Dataset
# #### Link: https://www.kaggle.com/datasets/kumarajarshi/life-expectancy-who

# %%
# Import the dataset using Pandas
df_3 = pd.read_csv('Life_Expectancy.csv')
df_3
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0                62     0.01               71.279624         65.0      1154
# 1                64     0.01               73.523582         62.0       492
# 2                66     0.01               73.219243         64.0       430
# 3                69     0.01               78.184215         67.0      2787
# 4                71     0.01                7.097109         68.0      3013
# ...             ...      ...                     ...          ...       ...
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0     ...    6.0               8.16         65.0        0.1  584.259210
# 1     ...   58.0               8.18         62.0        0.1  612.696514
# 2     ...   62.0               8.13         64.0        0.1  631.744976
# 3     ...   67.0               8.52         67.0        0.1  669.959000
# 4     ...   68.0               7.87         68.0        0.1   63.537231
# ...   ...    ...                ...          ...        ...         ...
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0     33736494.0                   17.2                 17.3
# 1       327582.0                   17.5                 17.5
# 2     31731688.0                   17.7                 17.7
# 3      3696958.0                   17.9                 18.0
# 4      2978599.0                   18.2                 18.2
# ...          ...                    ...                  ...
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %%
df_3.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df_3.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [5 rows x 22 columns]

# %%
df_3.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.877500                4.685343    77.000000       0.000000
# 50%       3.755000               64.912906    92.000000      17.000000
# 75%       7.702500              441.534144    97.000000     360.250000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#               BMI   under-five deaths         Polio  Total expenditure  \
# count  2904.000000         2938.000000  2919.000000         2712.00000
# mean     38.321247           42.035739    82.550188            5.93819
# std      20.044034          160.445548    23.428046            2.49832
# min       1.000000            0.000000     3.000000            0.37000
# 25%      19.300000            0.000000    78.000000            4.26000
# 50%      43.500000            4.000000    93.000000            5.75500
# 75%      56.200000           28.000000    97.000000            7.49250
# max      87.300000         2500.000000    99.000000           17.60000
#
#        Diphtheria      HIV/AIDS            GDP    Population  \
# count  2919.000000  2938.000000    2490.000000  2.286000e+03
# mean     82.324084     1.742103    7483.158469  1.275338e+07
# std      23.716912     5.077785   14270.169342  6.101210e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      78.000000     0.100000     463.935626  1.957932e+05
# 50%      93.000000     0.100000    1766.947595  1.386542e+06
# 75%      97.000000     0.800000    5910.806335  7.420359e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#         thinness  1-19 years   thinness 5-9 years  \
# count            2904.000000          2904.000000
# mean                4.839704             4.870317
# std                 4.420195             4.508882
# min                 0.100000             0.100000
# 25%                 1.600000             1.500000
# 50%                 3.300000             3.300000
# 75%                 7.200000             7.200000
# max                27.700000            28.600000
#
#        Income composition of resources    Schooling
# count                      2771.000000  2775.000000
# mean                          0.627551    11.992793
# std                           0.210904     3.358920
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.677000    12.300000
# 75%                           0.779000    14.300000
# max                           0.948000    20.700000

# %%
df_3.isna()
# Out:
#       Country   Year  Status  Life expectancy   Adult Mortality  \
# 0       False  False   False             False            False
# 1       False  False   False             False            False
# 2       False  False   False             False            False
# 3       False  False   False             False            False
# 4       False  False   False             False            False
# ...       ...    ...     ...               ...              ...
# 2933    False  False   False             False            False
# 2934    False  False   False             False            False
# 2935    False  False   False             False            False
# 2936    False  False   False             False            False
# 2937    False  False   False             False            False
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             False    False                   False        False     False
# 1             False    False                   False        False     False
# 2             False    False                   False        False     False
# 3             False    False                   False        False     False
# 4             False    False                   False        False     False
# ...             ...      ...                     ...          ...       ...
# 2933          False    False                   False        False     False
# 2934          False    False                   False        False     False
# 2935          False    False                   False        False     False
# 2936          False    False                   False        False     False
# 2937          False    False                   False        False     False
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS    GDP  \
# 0     ...  False              False        False      False  False
# 1     ...  False              False        False      False  False
# 2     ...  False              False        False      False  False
# 3     ...  False              False        False      False  False
# 4     ...  False              False        False      False  False
# ...   ...    ...                ...          ...        ...    ...
# 2933  ...  False              False        False      False  False
# 2934  ...  False              False        False      False  False
# 2935  ...  False              False        False      False  False
# 2936  ...  False              False        False      False  False
# 2937  ...  False              False        False      False  False
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0          False                  False                False
# 1          False                  False                False
# 2          False                  False                False
# 3          False                  False                False
# 4          False                  False                False
# ...          ...                    ...                  ...
# 2933       False                  False                False
# 2934       False                  False                False
# 2935       False                  False                False
# 2936       False                  False                False
# 2937       False                  False                False
#
#       Income composition of resources  Schooling
# 0                               False      False
# 1                               False      False
# 2                               False      False
# 3                               False      False
# 4                               False      False
# ...                               ...        ...
# 2933                            False      False
# 2934                            False      False
# 2935                            False      False
# 2936                            False      False
# 2937                            False      False
#
# [2938 rows x 22 columns]

# %%
# Select only numeric coloumn 
df_3_new = df_3.select_dtypes(include=['int64', 'float64'])
df_3_new.corr()
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.170033        -0.079052
# Life expectancy                  0.170033          1.000000        -0.696359
# Adult Mortality                 -0.079052         -0.696359         1.000000
# infant deaths                   -0.037415         -0.196557         0.078756
# Alcohol                         -0.052990          0.404877        -0.195848
# percentage expenditure           0.031400          0.381864        -0.242860
# Hepatitis B                      0.104333          0.256762        -0.162476
# Measles                         -0.082493         -0.157586         0.031176
#  BMI                             0.108974          0.567694        -0.387017
# under-five deaths               -0.042937         -0.222529         0.094146
# Polio                            0.094158          0.465556        -0.274823
# Total expenditure                0.090740          0.218086        -0.115281
# Diphtheria                       0.134337          0.479495        -0.275131
#  HIV/AIDS                       -0.139741         -0.556556         0.523821
# GDP                              0.101620          0.461455        -0.296049
# Population                       0.016969         -0.021538        -0.013647
#  thinness  1-19 years           -0.047876         -0.477183         0.302904
#  thinness 5-9 years             -0.050929         -0.471584         0.308457
# Income composition of resources  0.243468          0.724776        -0.457626
# Schooling                        0.209400          0.751975        -0.454612
#
#                                  infant deaths   Alcohol  \
# Year                                 -0.037415 -0.052990
# Life expectancy                      -0.196557  0.404877
# Adult Mortality                       0.078756 -0.195848
# infant deaths                         1.000000 -0.115638
# Alcohol                              -0.115638  1.000000
# percentage expenditure               -0.085612  0.341285
# Hepatitis B                          -0.223566  0.087549
# Measles                               0.501128 -0.051827
#  BMI                                 -0.227279  0.330408
# under-five deaths                     0.996629 -0.112370
# Polio                                -0.170689  0.221734
# Total expenditure                    -0.128616  0.296942
# Diphtheria                           -0.175171  0.222020
#  HIV/AIDS                             0.025231 -0.048845
# GDP                                  -0.108427  0.354712
# Population                            0.556801 -0.035252
#  thinness  1-19 years                 0.465711 -0.428795
#  thinness 5-9 years                   0.471350 -0.417414
# Income composition of resources      -0.145139  0.450040
# Schooling                            -0.193720  0.547378
#
#                                  percentage expenditure  Hepatitis B  \
# Year                                           0.031400     0.104333
# Life expectancy                                0.381864     0.256762
# Adult Mortality                               -0.242860    -0.162476
# infant deaths                                 -0.085612    -0.223566
# Alcohol                                        0.341285     0.087549
# percentage expenditure                         1.000000     0.016274
# Hepatitis B                                    0.016274     1.000000
# Measles                                       -0.056596    -0.120529
#  BMI                                           0.228700     0.150380
# under-five deaths                             -0.087852    -0.233126
# Polio                                          0.147259     0.486171
# Total expenditure                              0.174420     0.058280
# Diphtheria                                     0.143624     0.611495
#  HIV/AIDS                                     -0.097857    -0.112675
# GDP                                            0.899373     0.083903
# Population                                    -0.025662    -0.123321
#  thinness  1-19 years                         -0.251369    -0.120429
#  thinness 5-9 years                           -0.252905    -0.124960
# Income composition of resources                0.381952     0.199549
# Schooling                                      0.389687     0.231117
#
#                                  Measles       BMI   under-five deaths   \
# Year                            -0.082493  0.108974           -0.042937
# Life expectancy                 -0.157586  0.567694           -0.222529
# Adult Mortality                  0.031176 -0.387017            0.094146
# infant deaths                    0.501128 -0.227279            0.996629
# Alcohol                         -0.051827  0.330408           -0.112370
# percentage expenditure          -0.056596  0.228700           -0.087852
# Hepatitis B                     -0.120529  0.150380           -0.233126
# Measles                          1.000000 -0.175977            0.507809
#  BMI                            -0.175977  1.000000           -0.237669
# under-five deaths                0.507809 -0.237669            1.000000
# Polio                           -0.136166  0.284569           -0.188720
# Total expenditure               -0.106241  0.242503           -0.130148
# Diphtheria                      -0.141882  0.283147           -0.195668
#  HIV/AIDS                        0.030899 -0.243717            0.038062
# GDP                             -0.076466  0.301557           -0.112081
# Population                       0.265966 -0.072301            0.544423
#  thinness  1-19 years            0.224808 -0.532025            0.467789
#  thinness 5-9 years              0.221072 -0.538911            0.472263
# Income composition of resources -0.129568  0.508774           -0.163305
# Schooling                       -0.137225  0.546961           -0.209373
#
#                                     Polio  Total expenditure  Diphtheria   \
# Year                             0.094158           0.090740     0.134337
# Life expectancy                  0.465556           0.218086     0.479495
# Adult Mortality                 -0.274823          -0.115281    -0.275131
# infant deaths                   -0.170689          -0.128616    -0.175171
# Alcohol                          0.221734           0.296942     0.222020
# percentage expenditure           0.147259           0.174420     0.143624
# Hepatitis B                      0.486171           0.058280     0.611495
# Measles                         -0.136166          -0.106241    -0.141882
#  BMI                             0.284569           0.242503     0.283147
# under-five deaths               -0.188720          -0.130148    -0.195668
# Polio                            1.000000           0.137330     0.673553
# Total expenditure                0.137330           1.000000     0.152754
# Diphtheria                       0.673553           0.152754     1.000000
#  HIV/AIDS                       -0.159560          -0.001389    -0.164860
# GDP                              0.211976           0.138364     0.200666
# Population                      -0.038540          -0.079662    -0.028444
#  thinness  1-19 years           -0.221823          -0.277101    -0.229518
#  thinness 5-9 years             -0.222592          -0.283774    -0.222743
# Income composition of resources  0.381078           0.166682     0.401456
# Schooling                        0.417866           0.246384     0.425332
#
#                                   HIV/AIDS       GDP  Population  \
# Year                             -0.139741  0.101620    0.016969
# Life expectancy                  -0.556556  0.461455   -0.021538
# Adult Mortality                   0.523821 -0.296049   -0.013647
# infant deaths                     0.025231 -0.108427    0.556801
# Alcohol                          -0.048845  0.354712   -0.035252
# percentage expenditure           -0.097857  0.899373   -0.025662
# Hepatitis B                      -0.112675  0.083903   -0.123321
# Measles                           0.030899 -0.076466    0.265966
#  BMI                             -0.243717  0.301557   -0.072301
# under-five deaths                 0.038062 -0.112081    0.544423
# Polio                            -0.159560  0.211976   -0.038540
# Total expenditure                -0.001389  0.138364   -0.079662
# Diphtheria                       -0.164860  0.200666   -0.028444
#  HIV/AIDS                         1.000000 -0.136491   -0.027854
# GDP                              -0.136491  1.000000   -0.028270
# Population                       -0.027854 -0.028270    1.000000
#  thinness  1-19 years             0.204064 -0.285697    0.253944
#  thinness 5-9 years               0.207283 -0.290539    0.251403
# Income composition of resources  -0.249519  0.460341   -0.008735
# Schooling                        -0.220429  0.448273   -0.031668
#
#                                   thinness  1-19 years   thinness 5-9 years  \
# Year                                         -0.047876            -0.050929
# Life expectancy                              -0.477183            -0.471584
# Adult Mortality                               0.302904             0.308457
# infant deaths                                 0.465711             0.471350
# Alcohol                                      -0.428795            -0.417414
# percentage expenditure                       -0.251369            -0.252905
# Hepatitis B                                  -0.120429            -0.124960
# Measles                                       0.224808             0.221072
#  BMI                                         -0.532025            -0.538911
# under-five deaths                             0.467789             0.472263
# Polio                                        -0.221823            -0.222592
# Total expenditure                            -0.277101            -0.283774
# Diphtheria                                   -0.229518            -0.222743
#  HIV/AIDS                                     0.204064             0.207283
# GDP                                          -0.285697            -0.290539
# Population                                    0.253944             0.251403
#  thinness  1-19 years                         1.000000             0.939102
#  thinness 5-9 years                           0.939102             1.000000
# Income composition of resources              -0.422429            -0.411053
# Schooling                                    -0.471652            -0.460632
#
#                                  Income composition of resources  Schooling
# Year                                                    0.243468   0.209400
# Life expectancy                                         0.724776   0.751975
# Adult Mortality                                        -0.457626  -0.454612
# infant deaths                                          -0.145139  -0.193720
# Alcohol                                                 0.450040   0.547378
# percentage expenditure                                  0.381952   0.389687
# Hepatitis B                                             0.199549   0.231117
# Measles                                                -0.129568  -0.137225
#  BMI                                                    0.508774   0.546961
# under-five deaths                                      -0.163305  -0.209373
# Polio                                                   0.381078   0.417866
# Total expenditure                                       0.166682   0.246384
# Diphtheria                                              0.401456   0.425332
#  HIV/AIDS                                              -0.249519  -0.220429
# GDP                                                     0.460341   0.448273
# Population                                             -0.008735  -0.031668
#  thinness  1-19 years                                  -0.422429  -0.471652
#  thinness 5-9 years                                    -0.411053  -0.460632
# Income composition of resources                         1.000000   0.800092
# Schooling                                               0.800092   1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_3_new.corr(), annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
ax = df_3.plot.kde(subplots=True, layout=(5,4), figsize=(18, 6), sharex=False, legend=False)
# Add space between subplots
plt.subplots_adjust(hspace=0.5, wspace=0.5)

# Adding labels to axes
for i, axes_row in enumerate(ax):
    for j, ax in enumerate(axes_row):
        ax.set_xlabel(df_3.columns[i*2+j])
        ax.set_ylabel('Density')

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=df_3, x=df_3.columns[3], y=df_3.columns[16], lowess=True, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.show()

# %%
df_3.hist(bins=10, figsize=(12, 8), layout=(5, 4), color='skyblue', edgecolor='black')

plt.suptitle('Life Expectancy Data', y=1.03)    
plt.tight_layout()

plt.show()

# %%
attribute1=df_3.columns[3]
attribute2=df_3.columns[16]
sns.jointplot(data=df_3, x=attribute1, y=attribute2, hue="Status")

# %%
# Discretize the x-axis variable into 10 categories
plt.figure(figsize=(15, 6))
df_3['Life_Expectancy'] = pd.cut(df_3[df_3.columns[3]], bins=10)
sns.boxplot(x='Life_Expectancy', y=df_3.columns[16], hue='Status', data=df_3, dodge=True)
# Out:
# <AxesSubplot:xlabel='Life_Expectancy', ylabel='GDP'>

# %%
g = sns.PairGrid(df_3, x_vars=[df_3.columns[3], df_3.columns[4], df_3.columns[5],df_3.columns[6],df_3.columns[7],df_3.columns[8]], y_vars=[df_3.columns[3], df_3.columns[4], df_3.columns[5],df_3.columns[6],df_3.columns[7],df_3.columns[8]], hue='Status')
g = g.map_upper(plt.scatter)
#g = g.map(sns.regplot, color=".3")
g = g.map_diag(plt.hist, histtype="step", linewidth=2, bins=30)
# g = g.map_diag(plt.hist)
# g = g.map_offdiag(plt.scatter)
#g = g.map_lower(sns.kdeplot)
g = g.map_lower(plt.scatter)
g = g.add_legend()

# %% [markdown]
# 1. why did you pick this dataset?
# 2. are there any interesting insights you gained from performing EDA on this dataset? (use all/most of the Seaborn tools we discussed this week)
# 3. are there any actionable insights you can get from this data? (For example, if you were a CEO and looking at the mpg dataset, what might you conclude?)
#
# #### 1. The Life Expectancy (WHO) dataset was chosen due to its social and public health significance. Understanding the factors influencing life expectancy can have substantial implications for healthcare policies, education, and overall societal well-being.
# #### 2. TThrough a histogram, I observed that life expectancy values in the dataset form a roughly normal distribution with a peak around 75 years. By creating a correlation heatmap, I found that factors such as GDP, education, and immunization coverage were positively correlated with life expectancy.
# #### 3. EDA results provide valuable insights provide valuable information for shaping public health policies and programs. It would be crucial to prioritize initiatives that address socioeconomic disparities, improve access to education and healthcare, and promote healthy behaviors such as responsible alcohol consumption.

# %% [markdown]
# ____
# ## Pandas Practice
#
# ✍🏻  (10pts) From the standard penguins dataset, answer this question: what percentage of female penguins from Dream have a body mass greater than $4000$ grams? (Use only Pandas attributes and methods. Show your code as well as your answer.)
#
# [Hint.](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html)

# %%
import seaborn as sns
# Load the penguins dataset
df_penguins = sns.load_dataset('penguins')
df_penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
df_penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
# Filter for female penguins from Dream with body mass > 4000 grams
female_dream_penguins = df_penguins[(df_penguins['sex'] == 'Female') & (df_penguins['island'] == 'Dream') & (df_penguins['body_mass_g'] > 4000)]
female_dream_penguins
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 160  Chinstrap  Dream            46.0           18.9              195.0
#
#      body_mass_g     sex
# 160       4150.0  Female

# %%
# Calculate the percentage with respect to Dream island
percentage_female_dream_penguins_above_4000g = (len(female_dream_penguins) / len(df_penguins[df_penguins['island'] == 'Dream'])) * 100

print(f"The percentage of female penguins from Dream with a body mass greater than 4000 grams is: {percentage_female_dream_penguins_above_4000g:.2f}%")
# Out:
# The percentage of female penguins from Dream with a body mass greater than 4000 grams is: 0.81%

# %%
# Calculate the percentage with respect to total dataset
percentage_female_dream_penguins_above_4000g = (len(female_dream_penguins) / len(df_penguins)) * 100

print(f"The percentage of female penguins from Dream with a body mass greater than 4000 grams is: {percentage_female_dream_penguins_above_4000g:.2f}%")
# Out:
# The percentage of female penguins from Dream with a body mass greater than 4000 grams is: 0.29%

# %% [markdown]
# ____
# ## Python Practice
#
# ✍🏻 (5 pts) Run each of these codes and explain what how keywords work in Python functions.

# %%
def who_I_am(name, class_number, department):
  print(f"Hello. My name is {name} and I am in {department} {class_number} this semester.")

def who_I_am_kw(name, class_number=830, department="CMSE"):
  print(f"Hello. My name is {name} and I am in {department} {class_number} this semester.")

# %%
who_I_am("John", 830, "CMSE")
# Out:
# Hello. My name is John and I am in CMSE 830 this semester.

# %% [markdown]
# #### `who_I_am` function have no parameter with a default value.
# #### This call `who_I_am` function with value "John", 830, and "CMSE". And `who_I_am` function print accordingly.

# %%
who_I_am(830, "CMSE", "John")
# Out:
# Hello. My name is 830 and I am in John CMSE this semester.

# %% [markdown]
# #### This call `who_I_am` with `830, "CMSE", "John"` .

# %%
who_I_am(name = "John", class_number = 830, department = "CMSE")
# Out:
# Hello. My name is John and I am in CMSE 830 this semester.

# %%
who_I_am(department = "CMSE", class_number = 830, name = "John")
# Out:
# Hello. My name is John and I am in CMSE 830 this semester.

# %% [markdown]
# #### This call `who_I_am` with `department = "CMSE", class_number = 830, name = "John"`. As parameter value was assigned, so we can call the function with parameter withour order.

# %%
who_I_am_kw("Jack")
# Out:
# Hello. My name is Jack and I am in CMSE 830 this semester.

# %% [markdown]
# #### This call `who_I_am` with name = "John"`. As other parameter was defined previously, it works properly.

# %%
who_I_am_kw("Jack", class_number = 123)
# Out:
# Hello. My name is Jack and I am in CMSE 123 this semester.

# %% [markdown]
# #### This call `who_I_am_kw` with `"Jack", class_number = 123` and  department="CMSE" was default value for this function. So worked properly.

# %%
who_I_am_kw(class_number = 123, "Jack")
# Out:
#   File "/var/folders/69/255dld195d90vdnrvf2lk_f80000gn/T/ipykernel_39888/2915810975.py", line 1
#     who_I_am_kw(class_number = 123, "Jack")
#                                           ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# #### This call `who_I_am_kw` with `class_number = 123, "Jack"`.  When we use keyword arguments, all subsequent arguments must also be specified with keywords. In this case, trying to pass `"Jack"` as a positional argument after specifying `class_number` as a keyword argument. So `SyntaxError: positional argument follows keyword argument` occurs.

# %% [markdown]
# ____
# ## PEP-8
#
# ✍🏻 (5 pts) Which of these follows the [PEP-8 standard](https://peps.python.org/pep-0008/)?
#
# * `if x == 4 : print(x , y) ; x , y = y , x`
# * `if x == 4: print(x, y); x, y = y, x`
# * neither of these

# %% [markdown]
# #### Answer: The second option `if x == 4: print(x, y); x, y = y, x` follows the PEP-8 standard.
# * There are spaces around the comparison operator `==`, after the `if` statement, and before the colons. There are also spaces after the commas in the `print` statement. This conforms to the PEP-8 style guide for Python.

# %% [markdown]
# ____
# ## EDA: Seaborn and Correlations
#
# ✍🏻  (10pts) Read in the mpg dataset and perform EDA on it. Specifically:
# * get the basic statistics from the df,
# * make a `displot` of horsepower versus mpg, including a rug plot and with a kde,
# * make a Seaborn `heatmap` of the correlations using Pandas' `.corr`, with annotations and your choice of colormap,
# * make a `regplot` ([or, `lmplot`](https://seaborn.pydata.org/tutorial/regression.html)) of horsepower versus mpg using the lowess smoother; choose good colors,
# * design a `FacetGrid` of your choice.
#
# After each plot, open a markdown cell and give one sentence of what the plot tells you. That is, as a data scientist, what did this form of EDA reveal about the data? (If it didn't reveal anything to you, that is also an important possible answer.)

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataset
df_mpg = sns.load_dataset('mpg')
df_mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
# basic statistics
df_mpg.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
# Create a displot with joint KDE
#plt.figure(figsize=(12, 6))
sns.displot(data=df_mpg, x='horsepower', y='mpg', kind='kde', rug=True, height=6)
plt.title('Displot of Horsepower vs MPG with Joint KDE')
# Out:
# Text(0.5, 1.0, 'Displot of Horsepower vs MPG with Joint KDE')

# %% [markdown]
# #### The displot shows the distribution of horsepower and its relationship with mpg, revealing a negative correlation.

# %%
# Make a Seaborn heatmap of correlations
correlation_matrix = df_mpg.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(data=correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# #### The heatmap illustrates the correlations between different features, with darker colors indicating stronger relationships.

# %%
# Make a regplot of horsepower versus mpg using lowess smoother
plt.figure(figsize=(10, 6))
sns.regplot(data=df_mpg, x='horsepower', y='mpg', lowess=True, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title('Regplot of Horsepower vs MPG with Lowess Smoother')
plt.show()

# %% [markdown]
# #### The regplot displays a non-linear relationship between horsepower and mpg, suggesting that as horsepower increases, mpg tends to decrease.

# %%
# Design a FacetGrid of your choice (for example, cylinders vs. displacement)
g = sns.FacetGrid(data=df_mpg, col='cylinders')
g.map(plt.scatter, 'displacement', 'mpg', alpha=0.5)
g.set_axis_labels('Displacement', 'MPG')
g.fig.suptitle('FacetGrid of Cylinders vs Displacement vs MPG', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### The FacetGrid allows us to see the relationship between `Displacement` and `MPG` for different origin regions, showing variation in the patterns.

# %%
# Design a FacetGrid of your choice (for example, cylinders vs. displacement)
sns.FacetGrid(data=df_mpg, col='cylinders')
g.map(plt.scatter, 'horsepower', 'mpg', alpha=0.5)
g.set_axis_labels('Horsepower', 'MPG')
g.fig.suptitle('FacetGrid of Cylinders vs Horsepower vs MPG', y=1.02)
g.add_legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### The FacetGrid allows us to see the relationship between `Horsepower` and `MPG` for different origin regions, showing variation in the patterns.
